# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()
spark = SparkSession. \
builder. \
config('spark.ui.port', '0'). \
config("spark.sql.warehouse.dir", f"/user/{username}/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://g01.itversity.com:35449">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
orders_df = spark.read\
.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load("/public/trendytech/orders/*")

# %%
orders_df.show()
# Out:
# +---+---------------------+-----+---------------+
# |  1|2013-07-25 00:00:00.0|11599|         CLOSED|
# +---+---------------------+-----+---------------+
# |  2| 2013-07-25 00:00:...|  256|PENDING_PAYMENT|
# |  3| 2013-07-25 00:00:...|12111|       COMPLETE|
# |  4| 2013-07-25 00:00:...| 8827|         CLOSED|
# |  5| 2013-07-25 00:00:...|11318|       COMPLETE|
# |  6| 2013-07-25 00:00:...| 7130|       COMPLETE|
# |  7| 2013-07-25 00:00:...| 4530|       COMPLETE|
# |  8| 2013-07-25 00:00:...| 2911|     PROCESSING|
# |  9| 2013-07-25 00:00:...| 5657|PENDING_PAYMENT|
# | 10| 2013-07-25 00:00:...| 5648|PENDING_PAYMENT|
# | 11| 2013-07-25 00:00:...|  918| PAYMENT_REVIEW|
# | 12| 2013-07-25 00:00:...| 1837|         CLOSED|
# | 13| 2013-07-25 00:00:...| 9149|PENDING_PAYMENT|
# | 14| 2013-07-25 00:00:...| 9842|     PROCESSING|
# | 15| 2013-07-25 00:00:...| 2568|       COMPLETE|
# | 16| 2013-07-25 00:00:...| 7276|PENDING_PAYMENT|
# | 17| 2013-07-25 00:00:...| 2667|       COMPLETE|
# | 18| 2013-07-25 00:00:...| 1205|         CLOSED|
# | 19| 2013-07-25 00:00:...| 9488|PENDING_PAYMENT|
# | 20| 2013-07-25 00:00:...| 9198|     PROCESSING|
# | 21| 2013-07-25 00:00:...| 2711|        PENDING|
# +---+---------------------+-----+---------------+
# only showing top 20 rows

# %%
orders_df = orders_df.withColumnRenamed("1","order_id")

# %%
orders_df = orders_df.withColumnRenamed("2013-07-25 00:00:00.0","order_date")

# %%
orders_df = orders_df.withColumnRenamed("CLOSED","Status")

# %%
transformed_df1 = orders_df.withColumnRenamed("11599","Customer_id")

# %%
transformed_df1.show()
# Out:
# +--------+--------------------+-----------+---------------+
# |order_id|          order_date|Customer_id|         Status|
# +--------+--------------------+-----------+---------------+
# |       2|2013-07-25 00:00:...|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:...|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:...|       8827|         CLOSED|
# |       5|2013-07-25 00:00:...|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:...|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:...|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:...|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:...|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:...|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:...|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:...|       1837|         CLOSED|
# |      13|2013-07-25 00:00:...|       9149|PENDING_PAYMENT|
# |      14|2013-07-25 00:00:...|       9842|     PROCESSING|
# |      15|2013-07-25 00:00:...|       2568|       COMPLETE|
# |      16|2013-07-25 00:00:...|       7276|PENDING_PAYMENT|
# |      17|2013-07-25 00:00:...|       2667|       COMPLETE|
# |      18|2013-07-25 00:00:...|       1205|         CLOSED|
# |      19|2013-07-25 00:00:...|       9488|PENDING_PAYMENT|
# |      20|2013-07-25 00:00:...|       9198|     PROCESSING|
# |      21|2013-07-25 00:00:...|       2711|        PENDING|
# +--------+--------------------+-----------+---------------+
# only showing top 20 rows

# %%
print("Hello")
# Out:
# Hello

# %%
from pyspark.sql.functions import *

# %%
transformed_df2 = transformed_df1.withColumn("order_date_new",to_timestamp("order_date"))

# %%
transformed_df2.show()
# Out:
# +--------+--------------------+-----------+---------------+-------------------+
# |order_id|          order_date|Customer_id|         Status|     order_date_new|
# +--------+--------------------+-----------+---------------+-------------------+
# |       2|2013-07-25 00:00:...|        256|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       3|2013-07-25 00:00:...|      12111|       COMPLETE|2013-07-25 00:00:00|
# |       4|2013-07-25 00:00:...|       8827|         CLOSED|2013-07-25 00:00:00|
# |       5|2013-07-25 00:00:...|      11318|       COMPLETE|2013-07-25 00:00:00|
# |       6|2013-07-25 00:00:...|       7130|       COMPLETE|2013-07-25 00:00:00|
# |       7|2013-07-25 00:00:...|       4530|       COMPLETE|2013-07-25 00:00:00|
# |       8|2013-07-25 00:00:...|       2911|     PROCESSING|2013-07-25 00:00:00|
# |       9|2013-07-25 00:00:...|       5657|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      10|2013-07-25 00:00:...|       5648|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      11|2013-07-25 00:00:...|        918| PAYMENT_REVIEW|2013-07-25 00:00:00|
# |      12|2013-07-25 00:00:...|       1837|         CLOSED|2013-07-25 00:00:00|
# |      13|2013-07-25 00:00:...|       9149|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      14|2013-07-25 00:00:...|       9842|     PROCESSING|2013-07-25 00:00:00|
# |      15|2013-07-25 00:00:...|       2568|       COMPLETE|2013-07-25 00:00:00|
# |      16|2013-07-25 00:00:...|       7276|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      17|2013-07-25 00:00:...|       2667|       COMPLETE|2013-07-25 00:00:00|
# |      18|2013-07-25 00:00:...|       1205|         CLOSED|2013-07-25 00:00:00|
# |      19|2013-07-25 00:00:...|       9488|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      20|2013-07-25 00:00:...|       9198|     PROCESSING|2013-07-25 00:00:00|
# |      21|2013-07-25 00:00:...|       2711|        PENDING|2013-07-25 00:00:00|
# +--------+--------------------+-----------+---------------+-------------------+
# only showing top 20 rows

# %%
orders_df2 = spark.read \
.csv("/public/trendytech/orders/*", header="true", inferSchema="true")

# %%
orders_df2.show()
# Out:
# +---+---------------------+-----+---------------+
# |  1|2013-07-25 00:00:00.0|11599|         CLOSED|
# +---+---------------------+-----+---------------+
# |  2| 2013-07-25 00:00:...|  256|PENDING_PAYMENT|
# |  3| 2013-07-25 00:00:...|12111|       COMPLETE|
# |  4| 2013-07-25 00:00:...| 8827|         CLOSED|
# |  5| 2013-07-25 00:00:...|11318|       COMPLETE|
# |  6| 2013-07-25 00:00:...| 7130|       COMPLETE|
# |  7| 2013-07-25 00:00:...| 4530|       COMPLETE|
# |  8| 2013-07-25 00:00:...| 2911|     PROCESSING|
# |  9| 2013-07-25 00:00:...| 5657|PENDING_PAYMENT|
# | 10| 2013-07-25 00:00:...| 5648|PENDING_PAYMENT|
# | 11| 2013-07-25 00:00:...|  918| PAYMENT_REVIEW|
# | 12| 2013-07-25 00:00:...| 1837|         CLOSED|
# | 13| 2013-07-25 00:00:...| 9149|PENDING_PAYMENT|
# | 14| 2013-07-25 00:00:...| 9842|     PROCESSING|
# | 15| 2013-07-25 00:00:...| 2568|       COMPLETE|
# | 16| 2013-07-25 00:00:...| 7276|PENDING_PAYMENT|
# | 17| 2013-07-25 00:00:...| 2667|       COMPLETE|
# | 18| 2013-07-25 00:00:...| 1205|         CLOSED|
# | 19| 2013-07-25 00:00:...| 9488|PENDING_PAYMENT|
# | 20| 2013-07-25 00:00:...| 9198|     PROCESSING|
# | 21| 2013-07-25 00:00:...| 2711|        PENDING|
# +---+---------------------+-----+---------------+
# only showing top 20 rows

# %%
filtered_df = transformed_df2.where("customer_id = 12111")

# %%
filtered_df.show(truncate = False)
# Out:
# +--------+---------------------+-----------+---------------+-------------------+
# |order_id|order_date           |Customer_id|Status         |order_date_new     |
# +--------+---------------------+-----------+---------------+-------------------+
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# +--------+---------------------+-----------+---------------+-------------------+
# only showing top 20 rows

# %%
filtered_df = transformed_df2.filter("customer_id = 12111")

# %%
filtered_df.show(truncate = False)
# Out:
# +--------+---------------------+-----------+---------------+-------------------+
# |order_id|order_date           |Customer_id|Status         |order_date_new     |
# +--------+---------------------+-----------+---------------+-------------------+
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# |9017    |2013-09-19 00:00:00.0|12111      |COMPLETE       |2013-09-19 00:00:00|
# |45395   |2014-05-02 00:00:00.0|12111      |CANCELED       |2014-05-02 00:00:00|
# |55826   |2014-07-13 00:00:00.0|12111      |CLOSED         |2014-07-13 00:00:00|
# |56669   |2014-07-18 00:00:00.0|12111      |PENDING_PAYMENT|2014-07-18 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |3947    |2013-08-17 00:00:00.0|12111      |CLOSED         |2013-08-17 00:00:00|
# +--------+---------------------+-----------+---------------+-------------------+
# only showing top 20 rows

# %%
# where and filter does same role

# %%
transformed_df2.createOrReplaceTempView("orders") 

#conver a dataframe to a table or view
#we are getting a tabular view from the datadrame

# %%
filtered_df = spark.sql("select * from orders where Status = 'CLOSED' ")

#order is spark table and distributed across a cluster
#This will give you a dataframe as a result

# %%
filtered_df.show()
# Out:
# +--------+--------------------+-----------+------+-------------------+
# |order_id|          order_date|Customer_id|Status|     order_date_new|
# +--------+--------------------+-----------+------+-------------------+
# |       4|2013-07-25 00:00:...|       8827|CLOSED|2013-07-25 00:00:00|
# |      12|2013-07-25 00:00:...|       1837|CLOSED|2013-07-25 00:00:00|
# |      18|2013-07-25 00:00:...|       1205|CLOSED|2013-07-25 00:00:00|
# |      24|2013-07-25 00:00:...|      11441|CLOSED|2013-07-25 00:00:00|
# |      25|2013-07-25 00:00:...|       9503|CLOSED|2013-07-25 00:00:00|
# |      37|2013-07-25 00:00:...|       5863|CLOSED|2013-07-25 00:00:00|
# |      51|2013-07-25 00:00:...|      12271|CLOSED|2013-07-25 00:00:00|
# |      57|2013-07-25 00:00:...|       7073|CLOSED|2013-07-25 00:00:00|
# |      61|2013-07-25 00:00:...|       4791|CLOSED|2013-07-25 00:00:00|
# |      62|2013-07-25 00:00:...|       9111|CLOSED|2013-07-25 00:00:00|
# |      87|2013-07-25 00:00:...|       3065|CLOSED|2013-07-25 00:00:00|
# |      90|2013-07-25 00:00:...|       9131|CLOSED|2013-07-25 00:00:00|
# |     101|2013-07-25 00:00:...|       5116|CLOSED|2013-07-25 00:00:00|
# |     116|2013-07-26 00:00:...|       8763|CLOSED|2013-07-26 00:00:00|
# |     129|2013-07-26 00:00:...|       9937|CLOSED|2013-07-26 00:00:00|
# |     133|2013-07-26 00:00:...|      10604|CLOSED|2013-07-26 00:00:00|
# |     191|2013-07-26 00:00:...|         16|CLOSED|2013-07-26 00:00:00|
# |     201|2013-07-26 00:00:...|       9055|CLOSED|2013-07-26 00:00:00|
# |     211|2013-07-26 00:00:...|      10372|CLOSED|2013-07-26 00:00:00|
# |     213|2013-07-26 00:00:...|      11715|CLOSED|2013-07-26 00:00:00|
# +--------+--------------------+-----------+------+-------------------+
# only showing top 20 rows

# %%
#filtered_df is datadrame

# %%
ord_df = spark.read.table("orders")

#It will take a spark table which is orders and create a dataframe out of it

# %%
ord_df.show(truncate = False)
# Out:
# +--------+---------------------+-----------+---------------+-------------------+
# |order_id|order_date           |Customer_id|Status         |order_date_new     |
# +--------+---------------------+-----------+---------------+-------------------+
# |2       |2013-07-25 00:00:00.0|256        |PENDING_PAYMENT|2013-07-25 00:00:00|
# |3       |2013-07-25 00:00:00.0|12111      |COMPLETE       |2013-07-25 00:00:00|
# |4       |2013-07-25 00:00:00.0|8827       |CLOSED         |2013-07-25 00:00:00|
# |5       |2013-07-25 00:00:00.0|11318      |COMPLETE       |2013-07-25 00:00:00|
# |6       |2013-07-25 00:00:00.0|7130       |COMPLETE       |2013-07-25 00:00:00|
# |7       |2013-07-25 00:00:00.0|4530       |COMPLETE       |2013-07-25 00:00:00|
# |8       |2013-07-25 00:00:00.0|2911       |PROCESSING     |2013-07-25 00:00:00|
# |9       |2013-07-25 00:00:00.0|5657       |PENDING_PAYMENT|2013-07-25 00:00:00|
# |10      |2013-07-25 00:00:00.0|5648       |PENDING_PAYMENT|2013-07-25 00:00:00|
# |11      |2013-07-25 00:00:00.0|918        |PAYMENT_REVIEW |2013-07-25 00:00:00|
# |12      |2013-07-25 00:00:00.0|1837       |CLOSED         |2013-07-25 00:00:00|
# |13      |2013-07-25 00:00:00.0|9149       |PENDING_PAYMENT|2013-07-25 00:00:00|
# |14      |2013-07-25 00:00:00.0|9842       |PROCESSING     |2013-07-25 00:00:00|
# |15      |2013-07-25 00:00:00.0|2568       |COMPLETE       |2013-07-25 00:00:00|
# |16      |2013-07-25 00:00:00.0|7276       |PENDING_PAYMENT|2013-07-25 00:00:00|
# |17      |2013-07-25 00:00:00.0|2667       |COMPLETE       |2013-07-25 00:00:00|
# |18      |2013-07-25 00:00:00.0|1205       |CLOSED         |2013-07-25 00:00:00|
# |19      |2013-07-25 00:00:00.0|9488       |PENDING_PAYMENT|2013-07-25 00:00:00|
# |20      |2013-07-25 00:00:00.0|9198       |PROCESSING     |2013-07-25 00:00:00|
# |21      |2013-07-25 00:00:00.0|2711       |PENDING        |2013-07-25 00:00:00|
# +--------+---------------------+-----------+---------------+-------------------+
# only showing top 20 rows

# %%
ord_df.createOrReplaceGlobalTempView("orders")

# %%
spark.sql("create database if not exists itv024785_retail")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show databases").show()
# Out:
# +--------------------+
# |           namespace|
# +--------------------+
# |0000000000000_msdian|
# |0000000000000_nav...|
# |0000000009874_retail|
# |       0000000_pavan|
# |0000001_sample_it...|
# |          00000_2_db|
# |00000_aitv019314_...|
# |       00000assg5_db|
# |     00000assign5_db|
# |00000assign7_itv0...|
# |0000_0spark_tabbl...|
# |0000_1itv025021_l...|
# | 0000_cache_spark111|
# |        0000a5a5a5a5|
# |   0001_av_ivy_tesco|
# |     001_itv_grocery|
# |          001_retail|
# |        003402_hive1|
# |    005198_ivy_tesco|
# |    005212_ivy_tesco|
# +--------------------+
# only showing top 20 rows

# %%
spark.sql("show databases").filter("namespace = 'itv024785_retail'").show()
# Out:
# +----------------+
# |       namespace|
# +----------------+
# |itv024785_retail|
# +----------------+

# %%
spark.sql("show databases").filter("namespace like 'retail%'").show()
# Out:
# +-------------------+
# |          namespace|
# +-------------------+
# |             retail|
# |           retail01|
# |           retail02|
# |            retail1|
# |      retail1_dtata|
# |            retail2|
# |  retail2022_khalid|
# |            retail3|
# |       retail515_db|
# |      retail_012221|
# |      retail_012387|
# |retail_01_itv010328|
# |        retail_7969|
# |     retail_abhi_db|
# |    retail_adeeb_db|
# |       retail_aishu|
# |          retail_bk|
# |        retail_case|
# |          retail_cs|
# |           retail_d|
# +-------------------+
# only showing top 20 rows

# %%
spark.sql("show tables").show()
# Out:
# +--------+-----------------+-----------+
# |database|        tableName|isTemporary|
# +--------+-----------------+-----------+
# | default|            1htab|      false|
# | default|   41group_movies|      false|
# | default|    4group_movies|      false|
# | default|             4tab|      false|
# | default|    6_flags_simon|      false|
# | default|                a|      false|
# | default|               aa|      false|
# | default|              abc|      false|
# | default|             acid|      false|
# | default|            acid1|      false|
# | default|     acid_example|      false|
# | default|    acid_example1|      false|
# | default|    acid_example2|      false|
# | default|           adata1|      false|
# | default|        adata_ell|      false|
# | default|         adata_vr|      false|
# | default|    ad_earthquake|      false|
# | default|ad_earthquake_par|      false|
# | default|           adelta|      false|
# | default|       adeltapart|      false|
# +--------+-----------------+-----------+
# only showing top 20 rows

# %%
spark.sql("use retail")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables").show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |        |   orders|       true|
# +--------+---------+-----------+

# %%
spark.sql("use itv024785_retail")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables").show()
# Out:
# +----------------+---------+-----------+
# |        database|tableName|isTemporary|
# +----------------+---------+-----------+
# |itv024785_retail|   orders|      false|
# |                |   orders|       true|
# +----------------+---------+-----------+

# %%
spark.sql("create database if not exists itv024785_retail")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("use itv024785_retail")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables").show()
# Out:
# +----------------+---------+-----------+
# |        database|tableName|isTemporary|
# +----------------+---------+-----------+
# |itv024785_retail|   orders|      false|
# |                |   orders|       true|
# +----------------+---------+-----------+

# %%
spark.sql("select * from itv024785_retail.orders limit 5").show()
# Out:
# +--------+----------+-----------+------------+
# |order_id|order_date|customer_id|order_status|
# +--------+----------+-----------+------------+
# +--------+----------+-----------+------------+

# %%
spark.sql("select * from itv024785_retail.orders").show()
# Out:
# +--------+----------+-----------+------------+
# |order_id|order_date|customer_id|order_status|
# +--------+----------+-----------+------------+
# +--------+----------+-----------+------------+

# %%
spark.sql("select * from itv024785_retail.orders").show()
# Out:
# +--------+----------+-----------+------------+
# |order_id|order_date|customer_id|order_status|
# +--------+----------+-----------+------------+
# +--------+----------+-----------+------------+

# %%
spark.sql("describe table itv024785_retail.orders").show()

#Viewing metadata of the table
# Out:
# +------------+---------+-------+
# |    col_name|data_type|comment|
# +------------+---------+-------+
# |    order_id|      int|   null|
# |  order_date|   string|   null|
# | customer_id|      int|   null|
# |order_status|   string|   null|
# +------------+---------+-------+

# %%
spark.sql("describe extended itv024785_retail.orders").show()
# Out:
# +--------------------+--------------------+-------+
# |            col_name|           data_type|comment|
# +--------------------+--------------------+-------+
# |            order_id|                 int|   null|
# |          order_date|              string|   null|
# |         customer_id|                 int|   null|
# |        order_status|              string|   null|
# |                    |                    |       |
# |# Detailed Table ...|                    |       |
# |            Database|    itv024785_retail|       |
# |               Table|              orders|       |
# |               Owner|           itv024785|       |
# |        Created Time|Fri Mar 27 06:48:...|       |
# |         Last Access|             UNKNOWN|       |
# |          Created By|         Spark 3.1.2|       |
# |                Type|             MANAGED|       |
# |            Provider|                hive|       |
# |    Table Properties|[transient_lastDd...|       |
# |            Location|hdfs://m01.itvers...|       |
# |       Serde Library|org.apache.hadoop...|       |
# |         InputFormat|org.apache.hadoop...|       |
# |        OutputFormat|org.apache.hadoop...|       |
# |  Storage Properties|[serialization.fo...|       |
# +--------------------+--------------------+-------+
# only showing top 20 rows

# %%
spark.sql("describe extended itv024785_retail.orders").show(truncate=False)
# Out:
# +----------------------------+---------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                        |comment|
# +----------------------------+---------------------------------------------------------------------------------+-------+
# |order_id                    |int                                                                              |null   |
# |order_date                  |string                                                                           |null   |
# |customer_id                 |int                                                                              |null   |
# |order_status                |string                                                                           |null   |
# |                            |                                                                                 |       |
# |# Detailed Table Information|                                                                                 |       |
# |Database                    |itv024785_retail                                                                 |       |
# |Table                       |orders                                                                           |       |
# |Owner                       |itv024785                                                                        |       |
# |Created Time                |Fri Mar 27 06:48:52 EDT 2026                                                     |       |
# |Last Access                 |UNKNOWN                                                                          |       |
# |Created By                  |Spark 3.1.2                                                                      |       |
# |Type                        |MANAGED                                                                          |       |
# |Provider                    |hive                                                                             |       |
# |Table Properties            |[transient_lastDdlTime=1774608532]                                               |       |
# |Location                    |hdfs://m01.itversity.com:9000/user/itv024785/warehouse/itv024785_retail.db/orders|       |
# |Serde Library               |org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe                               |       |
# |InputFormat                 |org.apache.hadoop.mapred.TextInputFormat                                         |       |
# |OutputFormat                |org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat                       |       |
# |Storage Properties          |[serialization.format=1]                                                         |       |
# +----------------------------+---------------------------------------------------------------------------------+-------+
# only showing top 20 rows

# %%
spark.sql("drop table itv024785_retail.orders")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("create table itv024785_retail.orders(order_id integer, order_date string, customeer_id integer, order_status string) using csv")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("describe extended itv024785_retail.orders").show(truncate=False)
# Out:
# +----------------------------+---------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                        |comment|
# +----------------------------+---------------------------------------------------------------------------------+-------+
# |order_id                    |int                                                                              |null   |
# |order_date                  |string                                                                           |null   |
# |customeer_id                |int                                                                              |null   |
# |order_status                |string                                                                           |null   |
# |                            |                                                                                 |       |
# |# Detailed Table Information|                                                                                 |       |
# |Database                    |itv024785_retail                                                                 |       |
# |Table                       |orders                                                                           |       |
# |Owner                       |itv024785                                                                        |       |
# |Created Time                |Sat Mar 28 05:13:11 EDT 2026                                                     |       |
# |Last Access                 |UNKNOWN                                                                          |       |
# |Created By                  |Spark 3.1.2                                                                      |       |
# |Type                        |MANAGED                                                                          |       |
# |Provider                    |csv                                                                              |       |
# |Location                    |hdfs://m01.itversity.com:9000/user/itv024785/warehouse/itv024785_retail.db/orders|       |
# |Serde Library               |org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe                               |       |
# |InputFormat                 |org.apache.hadoop.mapred.SequenceFileInputFormat                                 |       |
# |OutputFormat                |org.apache.hadoop.hive.ql.io.HiveSequenceFileOutputFormat                        |       |
# +----------------------------+---------------------------------------------------------------------------------+-------+
